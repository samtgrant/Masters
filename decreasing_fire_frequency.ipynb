# %%
# Import libraries
import os
import glob
from osgeo import gdal
import numpy as np
import numpy.ma as ma
import matplotlib.pyplot as plt
import scipy.ndimage
import pandas as pd
import datetime as dt
import rasterio as rio
import re
import geopandas as gpd
import earthpy as et
import earthpy.plot as ep
import earthpy.spatial as es
import earthpy.mask as em
from pyhdf.SD import SD, SDC
import pprint
import gdal
from gdalconst import *
import matplotlib.colors as colors 
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
# Set input directory, and change working directory - plug in D:
inDir = "D:\\masters_data\\MODIS_BA"   
os.chdir(inDir)                                                               # Change to working directory
outDir = os.path.normpath(os.path.split(inDir)[0] + os.sep + 'output') + '\\' # Create and set output directory
if not os.path.exists(outDir): os.makedirs(outDir)

# %%
# select BA Files / year / tile - note there is multiple for each year 
BA_2002 = glob.glob('*MCD64A1.A2002**h20V08*')
BA_2003 = glob.glob('*MCD64A1.A2003**h20V08*')
BA_2004 = glob.glob('*MCD64A1.A2004**h20V08*')
BA_2005 = glob.glob('*MCD64A1.A2005**h20V08*')
BA_2006 = glob.glob('*MCD64A1.A2006**h20V08*')
BA_2007 = glob.glob('*MCD64A1.A2007**h20V08*')
BA_2008 = glob.glob('*MCD64A1.A2008**h20V08*')
BA_2009 = glob.glob('*MCD64A1.A2009**h20V08*')
BA_2010 = glob.glob('*MCD64A1.A2010**h20V08*')
BA_2011 = glob.glob('*MCD64A1.A2011**h20V08*')
BA_2012 = glob.glob('*MCD64A1.A2012**h20V08*')
BA_2013 = glob.glob('*MCD64A1.A2013**h20V08*')
BA_2014 = glob.glob('*MCD64A1.A2014**h20V08*')
BA_2015 = glob.glob('*MCD64A1.A2015**h20V08*')
BA_2016 = glob.glob('*MCD64A1.A2016**h20V08*')
BA_2017 = glob.glob('*MCD64A1.A2017**h20V08*')
BA_2018 = glob.glob('*MCD64A1.A2018**h20V08*')
BA_2019 = glob.glob('*MCD64A1.A2019**h20V08*')

# %%
# create blank array for each file - blanks is quite a poor name
blanks_2002 = np.zeros((2400, 2400))
blanks_2003 = np.zeros((2400, 2400))
blanks_2004 = np.zeros((2400, 2400))
blanks_2005 = np.zeros((2400, 2400))
blanks_2006 = np.zeros((2400, 2400))
blanks_2007 = np.zeros((2400, 2400))
blanks_2008 = np.zeros((2400, 2400))
blanks_2009 = np.zeros((2400, 2400))
blanks_2010 = np.zeros((2400, 2400))
blanks_2011 = np.zeros((2400, 2400))
blanks_2012 = np.zeros((2400, 2400))
blanks_2013 = np.zeros((2400, 2400))
blanks_2014 = np.zeros((2400, 2400))
blanks_2015 = np.zeros((2400, 2400))
blanks_2016 = np.zeros((2400, 2400))
blanks_2017 = np.zeros((2400, 2400))
blanks_2018 = np.zeros((2400, 2400))
blanks_2019 = np.zeros((2400, 2400))

# %%
# for each year, navigate through the burned area datasets. Find any place where the pixel has burnt that 
# month and add one to the corresponding blanks array 


#2002
NUMBER = 0
for j in BA_2002:
    filename= BA_2002[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(BA_2002[NUMBER]) as dataset:
        crs = dataset.read_crs()
    
    file_name = BA_2002[NUMBER]
    file = SD(file_name, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where(data > 0)
    
    blanks_2002[result] += 1
    
    NUMBER += 1

#2003
NUMBER = 0
for j in BA_2003:
    filename= BA_2003[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(BA_2003[NUMBER]) as dataset:
        crs = dataset.read_crs()
    
    file_name = BA_2003[NUMBER]
    file = SD(file_name, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where(data > 0)
    
    blanks_2003[result] += 1
    
    NUMBER += 1


#2004
NUMBER = 0
for j in BA_2004:
    filename= BA_2004[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(BA_2004[NUMBER]) as dataset:
        crs = dataset.read_crs()
    
    file_name = BA_2004[NUMBER]
    file = SD(file_name, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where(data > 0)
    
    blanks_2004[result] += 1
    
    NUMBER += 1
    
    
#2005
NUMBER = 0
for j in BA_2005:
    filename= BA_2005[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(BA_2005[NUMBER]) as dataset:
        crs = dataset.read_crs()
    
    file_name = BA_2005[NUMBER]
    file = SD(file_name, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where(data > 0)
    
    blanks_2005[result] += 1
    
    NUMBER += 1
    
    
#2006
NUMBER = 0
for j in BA_2006:
    filename= BA_2006[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(BA_2006[NUMBER]) as dataset:
        crs = dataset.read_crs()
    
    file_name = BA_2006[NUMBER]
    file = SD(file_name, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where(data > 0)
    
    blanks_2006[result] += 1
    
    NUMBER += 1
    
    
    
    
#2007
NUMBER = 0
for j in BA_2007:
    filename= BA_2007[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(BA_2007[NUMBER]) as dataset:
        crs = dataset.read_crs()
    
    file_name = BA_2007[NUMBER]
    file = SD(file_name, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where(data > 0)
    
    blanks_2007[result] += 1
    
    NUMBER += 1
    
    
    
    
#2008
NUMBER = 0
for j in BA_2008:
    filename= BA_2008[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(BA_2008[NUMBER]) as dataset:
        crs = dataset.read_crs()
    
    file_name = BA_2008[NUMBER]
    file = SD(file_name, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where(data > 0)
    
    blanks_2008[result] += 1
    
    NUMBER += 1
    
    
    
    
#2009
NUMBER = 0
for j in BA_2009:
    filename= BA_2009[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(BA_2009[NUMBER]) as dataset:
        crs = dataset.read_crs()
    
    file_name = BA_2009[NUMBER]
    file = SD(file_name, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where(data > 0)
    
    blanks_2009[result] += 1
    
    NUMBER += 1
    
    
    
#2010
NUMBER = 0
for j in BA_2010:
    filename= BA_2010[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(BA_2010[NUMBER]) as dataset:
        crs = dataset.read_crs()
    
    file_name = BA_2010[NUMBER]
    file = SD(file_name, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where(data > 0)
    
    blanks_2010[result] += 1
    
    NUMBER += 1
    
    
    
    
#2011
NUMBER = 0
for j in BA_2011:
    filename= BA_2011[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(BA_2011[NUMBER]) as dataset:
        crs = dataset.read_crs()
    
    file_name = BA_2011[NUMBER]
    file = SD(file_name, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where(data > 0)
    
    blanks_2011[result] += 1
    
    NUMBER += 1
    
    
    
#2012
NUMBER = 0
for j in BA_2012:
    filename= BA_2012[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(BA_2012[NUMBER]) as dataset:
        crs = dataset.read_crs()
    
    file_name = BA_2012[NUMBER]
    file = SD(file_name, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where(data > 0)
    
    blanks_2012[result] += 1
    
    NUMBER += 1
    
    
    
#2013
NUMBER = 0
for j in BA_2013:
    filename= BA_2013[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(BA_2013[NUMBER]) as dataset:
        crs = dataset.read_crs()
    
    file_name = BA_2013[NUMBER]
    file = SD(file_name, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where(data > 0)
    
    blanks_2013[result] += 1
    
    NUMBER += 1 
    
    
    
#2014
NUMBER = 0
for j in BA_2014:
    filename= BA_2014[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(BA_2014[NUMBER]) as dataset:
        crs = dataset.read_crs()
    
    file_name = BA_2014[NUMBER]
    file = SD(file_name, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where(data > 0)
    
    blanks_2014[result] += 1
    
    NUMBER += 1
    
    
    
#2015
NUMBER = 0
for j in BA_2015:
    filename= BA_2015[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(BA_2015[NUMBER]) as dataset:
        crs = dataset.read_crs()
    
    file_name = BA_2015[NUMBER]
    file = SD(file_name, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where(data > 0)
    
    blanks_2015[result] += 1
    
    NUMBER += 1
    
    
    
    
    
#2016
NUMBER = 0
for j in BA_2016:
    filename= BA_2016[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(BA_2016[NUMBER]) as dataset:
        crs = dataset.read_crs()
    
    file_name = BA_2016[NUMBER]
    file = SD(file_name, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where(data > 0)
    
    blanks_2016[result] += 1
    
    NUMBER += 1
    
    
    
#2017
NUMBER = 0
for j in BA_2017:
    filename= BA_2017[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(BA_2017[NUMBER]) as dataset:
        crs = dataset.read_crs()
    
    file_name = BA_2017[NUMBER]
    file = SD(file_name, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where(data > 0)
    
    blanks_2017[result] += 1
    
    NUMBER += 1
    
    
    
#2018
NUMBER = 0
for j in BA_2018:
    filename= BA_2018[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(BA_2018[NUMBER]) as dataset:
        crs = dataset.read_crs()
    
    file_name = BA_2018[NUMBER]
    file = SD(file_name, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where(data > 0)
    
    blanks_2018[result] += 1
    
    NUMBER += 1
    
    
    
#2019
NUMBER = 0
for j in BA_2019:
    filename= BA_2019[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(BA_2019[NUMBER]) as dataset:
        crs = dataset.read_crs()
    
    file_name = BA_2019[NUMBER]
    file = SD(file_name, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where(data > 0)
    
    blanks_2019[result] += 1
    
    NUMBER += 1
# Out:
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %%
# ignore - for some reason need this to run to make the next one work - sign of poor script!

import matplotlib.colors as colors 
from mpl_toolkits.axes_grid1 import make_axes_locatable 

u = np.unique(blanks_2002) 
bounds = np.concatenate(([blanks_2002.min()], 
                         u[:-1]+np.diff(u)/2., 
                         [blanks_2002.max()]))
    
fig, axes = plt.subplots() 
img = axes.imshow(blanks_2002, cmap = "OrRd", 
                  ) 
divider = make_axes_locatable(axes) 
cax = divider.append_axes("right", size ="5 %") 
  
color_bar = plt.colorbar(img,  
                        cax = cax) 
  
plt.show()
# Out:
# <ipython-input-6-5972f061cd34>:15: MatplotlibDeprecationWarning: In a future version, 'pad' will default to rcParams['figure.subplot.wspace'].  Set pad=0 to keep the old behavior.
#   cax = divider.append_axes("right", size ="5 %")

# %%
# plot the data to show blanks array for each useful - not really all that useful but still cool

#2002
plt.subplot(3,6,1)
color_map = plt.imshow(blanks_2002)
plt.title("2002")
img = axes.imshow(blanks_2002, vmin = 0, cmap = "PiYG")
plt.colorbar(img, cax = cax)
color_map.set_cmap("Set2")
divider = make_axes_locatable(axes) 
cax = divider.append_axes("right", size ="5 %")


#2003
plt.subplot(3,6,2)
color_map = plt.imshow(blanks_2003)
plt.title("2003")
img = axes.imshow(blanks_2003, vmin = 0, cmap = "Set2")
plt.colorbar(img, cax = cax)
color_map.set_cmap("Set2")


#2004
plt.subplot(3,6,3)
color_map = plt.imshow(blanks_2004)
plt.title("2004")
img = axes.imshow(blanks_2004, vmin = 0, cmap = "Set2")
plt.colorbar(img, cax = cax)
color_map.set_cmap("Set2")


#2005
plt.subplot(3,6,4)
color_map = plt.imshow(blanks_2005)
plt.title("2005")
img = axes.imshow(blanks_2005, vmin = 0, cmap = "Set2")
plt.colorbar(img, cax = cax)
color_map.set_cmap("Set2")


#2006
plt.subplot(3,6,5)
color_map = plt.imshow(blanks_2006)
plt.title("2006")
img = axes.imshow(blanks_2006, vmin = 0, cmap = "Set2")
plt.colorbar(img, cax = cax)
color_map.set_cmap("Set2")


#2007
plt.subplot(3,6,6)
color_map = plt.imshow(blanks_2007)
plt.title("2007")
img = axes.imshow(blanks_2007, vmin = 0, cmap = "Set2")
plt.colorbar(img, cax = cax)
color_map.set_cmap("Set2")


#2008
plt.subplot(3,6,7)
color_map = plt.imshow(blanks_2008)
plt.title("2008")
img = axes.imshow(blanks_2008, vmin = 0, cmap = "Set2")
plt.colorbar(img, cax = cax)
color_map.set_cmap("Set2")


#2009
plt.subplot(3,6,8)
color_map = plt.imshow(blanks_2009)
plt.title("2009")
img = axes.imshow(blanks_2009, vmin = 0, cmap = "Set2")
plt.colorbar(img, cax = cax)
color_map.set_cmap("Set2")


#2010
plt.subplot(3,6,9)
color_map = plt.imshow(blanks_2010)
plt.title("2010")
img = axes.imshow(blanks_2010, vmin = 0, cmap = "Set2")
plt.colorbar(img, cax = cax)
color_map.set_cmap("Set2")


#2011
plt.subplot(3,6,10)
color_map = plt.imshow(blanks_2011)
plt.title("2011")
img = axes.imshow(blanks_2011, vmin = 0, cmap = "Set2")
plt.colorbar(img, cax = cax)
color_map.set_cmap("Set2")


#2012
plt.subplot(3,6, 11)
color_map = plt.imshow(blanks_2012)
plt.title("2012")
img = axes.imshow(blanks_2012, vmin = 0, cmap = "Set2")
plt.colorbar(img, cax = cax)
color_map.set_cmap("Set2")


#2013
plt.subplot(3,6,12)
color_map = plt.imshow(blanks_2013)
plt.title("2013")
img = axes.imshow(blanks_2013, vmin = 0, cmap = "Set2")
plt.colorbar(img, cax = cax)
color_map.set_cmap("Set2")


#2014
plt.subplot(3,6,13)
color_map = plt.imshow(blanks_2014)
plt.title("2014")
img = axes.imshow(blanks_2014, vmin = 0, cmap = "Set2")
plt.colorbar(img, cax = cax)
color_map.set_cmap("Set2")


#2015
plt.subplot(3,6,14)
color_map = plt.imshow(blanks_2015)
plt.title("2015")
img = axes.imshow(blanks_2015, vmin = 0, cmap = "Set2")
plt.colorbar(img, cax = cax)
color_map.set_cmap("Set2")


#2016
plt.subplot(3,6,15)
color_map = plt.imshow(blanks_2016)
plt.title("2016")
img = axes.imshow(blanks_2016, vmin = 0, cmap = "Set2")
plt.colorbar(img, cax = cax)
color_map.set_cmap("Set2")



#2017
plt.subplot(3,6,16)
color_map = plt.imshow(blanks_2017)
plt.title("2017")
img = axes.imshow(blanks_2017, vmin = 0, cmap = "Set2")
plt.colorbar(img, cax = cax)
color_map.set_cmap("Set2")


#2018
plt.subplot(3,6,17)
color_map = plt.imshow(blanks_2018)
plt.title("2018")
img = axes.imshow(blanks_2018, vmin = 0, cmap = "Set2")
plt.colorbar(img, cax = cax)
color_map.set_cmap("Set2")

#2019
plt.subplot(3,6,18)
color_map = plt.imshow(blanks_2019)
plt.title("2019")
img = axes.imshow(blanks_2019, vmin = 0, cmap = "Set2")
plt.colorbar(img, cax = cax)
color_map.set_cmap("Set2")


plt.subplots_adjust(bottom=0, right=2.6, top=2.5)
# Out:
# <ipython-input-7-6c90a6ef28e8>:11: MatplotlibDeprecationWarning: In a future version, 'pad' will default to rcParams['figure.subplot.wspace'].  Set pad=0 to keep the old behavior.
#   cax = divider.append_axes("right", size ="5 %")

# %%
# next lets plot a graph of fire frequency in each year
# then maybe do one per month

# %%
# create a for loop printing total and mean for all of them
years = (blanks_2002, blanks_2003, blanks_2004, blanks_2005, blanks_2006, blanks_2007, blanks_2008, blanks_2009, blanks_2010, 
         blanks_2011, blanks_2012, blanks_2013, blanks_2014, blanks_2015, blanks_2016, blanks_2017, blanks_2018, blanks_2019)

# %%
year = []
_sum = []
mean = []
_min = []
_max = []

for i in range(18):
    print("Year:  {}       sum: {}       mean: {}       min: {}       max: {}"
          . format(i +2002, years[i].sum(), "{:.4f}".format(years[i].sum()/ (2400*2400)), years[i].min(), years[i].max()))
    
    year.append(i+2002)
    _sum.append(years[i].sum())
    mean.append("{:.4f}".format(years[i].sum()/ (2400*2400)))
    _min.append(years[i].min())
    _max.append(years[i].max())
# Out:
# Year:  2002       sum: 1409779.0       mean: 0.2448       min: 0.0       max: 4.0
# Year:  2003       sum: 1726540.0       mean: 0.2997       min: 0.0       max: 3.0
# Year:  2004       sum: 1649078.0       mean: 0.2863       min: 0.0       max: 4.0
# Year:  2005       sum: 1705689.0       mean: 0.2961       min: 0.0       max: 3.0
# Year:  2006       sum: 1455161.0       mean: 0.2526       min: 0.0       max: 3.0
# Year:  2007       sum: 1569935.0       mean: 0.2726       min: 0.0       max: 3.0
# Year:  2008       sum: 1741941.0       mean: 0.3024       min: 0.0       max: 3.0
# Year:  2009       sum: 1402748.0       mean: 0.2435       min: 0.0       max: 3.0
# Year:  2010       sum: 1354053.0       mean: 0.2351       min: 0.0       max: 3.0
# Year:  2011       sum: 1667882.0       mean: 0.2896       min: 0.0       max: 3.0
# Year:  2012       sum: 1350848.0       mean: 0.2345       min: 0.0       max: 3.0
# ...

# %%
plt.plot(year, _sum, color = "orange", linewidth = 1.75)
plt.title("change in Total Burned Area ")
plt.xlabel("year")
positions = (2000, 2005, 2010, 2015, 2020)
labels = ("2000", "2005", "2010", "2015", "2020")
plt.xticks(positions, labels)
plt.ylabel("sum of fires (millions)")
# Out:
# Text(0, 0.5, 'sum of fires (millions)')

# %%
# comparing 2003 to 2002 - this shows decrease in fire frequency over the year
blanks_0203 = np.zeros((2400, 2400))

for i in blanks_2003:
    result = np.where(np.less(blanks_2003, blanks_2002))
    blanks_0203[result] = blanks_2003[result]

# %% [markdown]
# NDVI

# %%
# Set input directory, and change working directory - plug in D:
inDir = "D:\\masters_data\\MODIS_VI"   # I should change this so I can work from github?
os.chdir(inDir)
outDir = os.path.normpath(os.path.split(inDir)[0] + os.sep + 'output') + '\\' # Create and set output directory
if not os.path.exists(outDir): os.makedirs(outDir)

# %%
VI_2002 = glob.glob('*MOD13A1.A2002**h20V08*')
VI_2003 = glob.glob('*MOD13A1.A2003**h20V08*')
VI_2004 = glob.glob('*MOD13A1.A2004**h20V08*')
VI_2005 = glob.glob('*MOD13A1.A2005**h20V08*')
VI_2006 = glob.glob('*MOD13A1.A2006**h20V08*')
VI_2007 = glob.glob('*MOD13A1.A2007**h20V08*')
VI_2008 = glob.glob('*MOD13A1.A2008**h20V08*')
VI_2009 = glob.glob('*MOD13A1.A2009**h20V08*')
VI_2010 = glob.glob('*MOD13A1.A2010**h20V08*')
VI_2011 = glob.glob('*MOD13A1.A2011**h20V08*')
VI_2012 = glob.glob('*MOD13A1.A2012**h20V08*')
VI_2013 = glob.glob('*MOD13A1.A2013**h20V08*')
VI_2014 = glob.glob('*MOD13A1.A2014**h20V08*')
VI_2015 = glob.glob('*MOD13A1.A2015**h20V08*')
VI_2016 = glob.glob('*MOD13A1.A2016**h20V08*')
VI_2017 = glob.glob('*MOD13A1.A2017**h20V08*')
VI_2018 = glob.glob('*MOD13A1.A2018**h20V08*')
VI_2019 = glob.glob('*MOD13A1.A2019**h20V08*')

# %%
# create blanks
VI_blanks_2002 = np.zeros((2400, 2400))
VI_blanks_2003 = np.zeros((2400, 2400))
VI_blanks_2004 = np.zeros((2400, 2400))
VI_blanks_2005 = np.zeros((2400, 2400))
VI_blanks_2006 = np.zeros((2400, 2400))
VI_blanks_2007 = np.zeros((2400, 2400))
VI_blanks_2008 = np.zeros((2400, 2400))
VI_blanks_2009 = np.zeros((2400, 2400))
VI_blanks_2010 = np.zeros((2400, 2400))
VI_blanks_2011 = np.zeros((2400, 2400))
VI_blanks_2012 = np.zeros((2400, 2400))
VI_blanks_2013 = np.zeros((2400, 2400))
VI_blanks_2014 = np.zeros((2400, 2400))
VI_blanks_2015 = np.zeros((2400, 2400))
VI_blanks_2016 = np.zeros((2400, 2400))
VI_blanks_2017 = np.zeros((2400, 2400))
VI_blanks_2018 = np.zeros((2400, 2400))
VI_blanks_2019 = np.zeros((2400, 2400))

# %%
# will dividing by zero create a problem?
Valid_VI_count_2002 = np.zeros((2400, 2400))
Valid_VI_count_2003 = np.zeros((2400, 2400))
Valid_VI_count_2004 = np.zeros((2400, 2400))
Valid_VI_count_2005 = np.zeros((2400, 2400))
Valid_VI_count_2006 = np.zeros((2400, 2400))
Valid_VI_count_2007 = np.zeros((2400, 2400))
Valid_VI_count_2008 = np.zeros((2400, 2400))
Valid_VI_count_2009 = np.zeros((2400, 2400))
Valid_VI_count_2010 = np.zeros((2400, 2400))
Valid_VI_count_2011 = np.zeros((2400, 2400))
Valid_VI_count_2012 = np.zeros((2400, 2400))
Valid_VI_count_2013 = np.zeros((2400, 2400))
Valid_VI_count_2014 = np.zeros((2400, 2400))
Valid_VI_count_2015 = np.zeros((2400, 2400))
Valid_VI_count_2016 = np.zeros((2400, 2400))
Valid_VI_count_2017 = np.zeros((2400, 2400))
Valid_VI_count_2018 = np.zeros((2400, 2400))

# %%
# 2002
number = 0   
for i in VI_2002:
    filename = VI_2002[number]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    with rio.open(filename) as dataset:
        crs = dataset.read_crs()
    file = SD(filename, SDC.READ)   
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    VI_data = sds_obj.get() 
    
    result = np.where(VI_data > -2999)
    VI_blanks_2002[result] += VI_data[result]
    Valid_VI_count_2002[result] += 1
    number += 1


# 2003
number = 0   
for i in VI_2003:
    filename = VI_2003[number]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    with rio.open(filename) as dataset:
        crs = dataset.read_crs()
    file = SD(filename, SDC.READ)   
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    VI_data = sds_obj.get() 
    
    result = np.where(VI_data > -2999)
    VI_blanks_2003[result] += VI_data[result]
    Valid_VI_count_2003[result] += 1
    number += 1
    

# 2004
number = 0   
for i in VI_2004:
    filename = VI_2004[number]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    with rio.open(filename) as dataset:
        crs = dataset.read_crs()
    file = SD(filename, SDC.READ)   
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    VI_data = sds_obj.get() 
    
    result = np.where(VI_data > -2999)
    VI_blanks_2004[result] += VI_data[result]
    Valid_VI_count_2004[result] += 1
    number += 1
    
    
# 2005
number = 0   
for i in VI_2005:
    filename = VI_2005[number]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    with rio.open(filename) as dataset:
        crs = dataset.read_crs()
    file = SD(filename, SDC.READ)   
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    VI_data = sds_obj.get() 
    
    result = np.where(VI_data > -2999)    
    VI_blanks_2005[result] += VI_data[result]
    Valid_VI_count_2005[result] += 1
    number += 1



# 2006
number = 0   
for i in VI_2006:
    filename = VI_2006[number]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    with rio.open(filename) as dataset:
        crs = dataset.read_crs()
    file = SD(filename, SDC.READ)   
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    VI_data = sds_obj.get() 
    
    result = np.where(VI_data > -2999)
    VI_blanks_2006[result] += VI_data[result]
    Valid_VI_count_2006[result] += 1
    number += 1
    
    
# 2007
number = 0   
for i in VI_2007:
    filename = VI_2007[number]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    with rio.open(filename) as dataset:
        crs = dataset.read_crs()
    file = SD(filename, SDC.READ)   
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    VI_data = sds_obj.get() 
    
    result = np.where(VI_data > -2999)
    VI_blanks_2007[result] += VI_data[result]
    Valid_VI_count_2007[result] += 1
    number += 1


# 2008
number = 0   
for i in VI_2008:
    filename = VI_2008[number]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    with rio.open(filename) as dataset:
        crs = dataset.read_crs()
    file = SD(filename, SDC.READ)   
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    VI_data = sds_obj.get() 
    
    result = np.where(VI_data > -2999)
    VI_blanks_2008[result] += VI_data[result]
    Valid_VI_count_2008[result] += 1
    number += 1
    

# 2009
number = 0   
for i in VI_2009:
    filename = VI_2009[number]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    with rio.open(filename) as dataset:
        crs = dataset.read_crs()
    file = SD(filename, SDC.READ)   
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    VI_data = sds_obj.get() 
    
    result = np.where(VI_data > -2999)
    VI_blanks_2009[result] += VI_data[result]
    Valid_VI_count_2009[result] += 1
    number += 1


# 2010
number = 0   
for i in VI_2010:
    filename = VI_2010[number]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    with rio.open(filename) as dataset:
        crs = dataset.read_crs()
    file = SD(filename, SDC.READ)   
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    VI_data = sds_obj.get() 
    
    result = np.where(VI_data > -2999)
    VI_blanks_2010[result] += VI_data[result]
    Valid_VI_count_2010[result] += 1
    number += 1


# 2011
number = 0   
for i in VI_2011:
    filename = VI_2011[number]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    with rio.open(filename) as dataset:
        crs = dataset.read_crs()
    file = SD(filename, SDC.READ)   
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    VI_data = sds_obj.get() 
    
    result = np.where(VI_data > -2999)
    VI_blanks_2011[result] += VI_data[result]
    Valid_VI_count_2011[result] += 1
    number += 1


# 2012
number = 0   
for i in VI_2012:
    filename = VI_2012[number]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    with rio.open(filename) as dataset:
        crs = dataset.read_crs()
    file = SD(filename, SDC.READ)   
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    VI_data = sds_obj.get() 
    
    result = np.where(VI_data > -2999)
    VI_blanks_2012[result] += VI_data[result]
    Valid_VI_count_2012[result] += 1
    number += 1



# 2013
number = 0   
for i in VI_2013:
    filename = VI_2013[number]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    with rio.open(filename) as dataset:
        crs = dataset.read_crs()
    file = SD(filename, SDC.READ)   
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    VI_data = sds_obj.get() 
    
    result = np.where(VI_data > -2999)
    VI_blanks_2013[result] += VI_data[result]
    Valid_VI_count_2013[result] += 1
    number += 1


# 2014
number = 0   
for i in VI_2014:
    filename = VI_2014[number]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    with rio.open(filename) as dataset:
        crs = dataset.read_crs()
    file = SD(filename, SDC.READ)   
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    VI_data = sds_obj.get() 
    
    result = np.where(VI_data > -2999)
    VI_blanks_2014[result] += VI_data[result]
    Valid_VI_count_2014[result] += 1
    number += 1


# 2015
number = 0   
for i in VI_2015:
    filename = VI_2015[number]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    with rio.open(filename) as dataset:
        crs = dataset.read_crs()
    file = SD(filename, SDC.READ)   
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    VI_data = sds_obj.get() 
    
    result = np.where(VI_data > -2999)
    VI_blanks_2015[result] += VI_data[result]
    Valid_VI_count_2015[result] += 1
    number += 1


# 2016
number = 0   
for i in VI_2016:
    filename = VI_2016[number]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    with rio.open(filename) as dataset:
        crs = dataset.read_crs()
    file = SD(filename, SDC.READ)   
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    VI_data = sds_obj.get() 
    
    result = np.where(VI_data > -2999)
    VI_blanks_2016[result] += VI_data[result]
    Valid_VI_count_2016[result] += 1
    number += 1



# 2017
number = 0   
for i in VI_2017:
    filename = VI_2017[number]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    with rio.open(filename) as dataset:
        crs = dataset.read_crs()
    file = SD(filename, SDC.READ)   
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    VI_data = sds_obj.get() 
    
    result = np.where(VI_data > -2999)
    VI_blanks_2017[result] += VI_data[result]
    Valid_VI_count_2017[result] += 1
    number += 1    


# 2018
number = 0   
for i in VI_2018:
    filename = VI_2018[number]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    with rio.open(filename) as dataset:
        crs = dataset.read_crs()
    file = SD(filename, SDC.READ)   
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    VI_data = sds_obj.get() 
    
    result = np.where(VI_data > -2999)
    VI_blanks_2018[result] += VI_data[result]
    Valid_VI_count_2018[result] += 1
    number += 1
    

# 2019
number = 0   
for i in VI_2019:
    filename = VI_2019[number]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    with rio.open(filename) as dataset:
        crs = dataset.read_crs()
    file = SD(filename, SDC.READ)   
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    
    VI_data = sds_obj.get() 
    result = np.where(VI_data > -2999)
    VI_blanks_2019[result] += VI_data[result]
    Valid_VI_count_2018[result] += 1
    number += 1

# %%
# create mean by dividing values by number of years
VI_mean_2002 = VI_blanks_2002 / number
VI_mean_2003 = VI_blanks_2003 / number
VI_mean_2004 = VI_blanks_2004 / number
VI_mean_2005 = VI_blanks_2005 / number
VI_mean_2006 = VI_blanks_2006 / number
VI_mean_2007 = VI_blanks_2007 / number
VI_mean_2008 = VI_blanks_2008 / number
VI_mean_2009 = VI_blanks_2009 / number
VI_mean_2010 = VI_blanks_2010 / number
VI_mean_2011 = VI_blanks_2011 / number
VI_mean_2012 = VI_blanks_2012 / number
VI_mean_2013 = VI_blanks_2013 / number
VI_mean_2014 = VI_blanks_2014 / number
VI_mean_2015 = VI_blanks_2015 / number
VI_mean_2016 = VI_blanks_2016 / number
VI_mean_2017 = VI_blanks_2017 / number
VI_mean_2018 = VI_blanks_2018 / number
VI_mean_2019 = VI_blanks_2019 / number

# %%
# this one would be pretty easy to forloop i think

# 2002 / 2003
blanks_0203 = np.zeros((2400, 2400))
for i in VI_blanks_2002:
    result = np.where(blanks_2002 > blanks_2003)
    blanks_0203[result] = VI_blanks_2003[result]

# 2003 / 2004
blanks_0304 = np.zeros((2400, 2400))
for i in VI_blanks_2003:
    result = np.where(blanks_2003 > blanks_2004)
    blanks_0304[result] = VI_blanks_2004[result]
    
# 2004 / 2005
blanks_0405 = np.zeros((2400, 2400))
for i in VI_blanks_2004:
    result = np.where(blanks_2004 > blanks_2005)
    blanks_0405[result] = VI_blanks_2005[result]

# 2005 / 2006
blanks_0506 = np.zeros((2400, 2400))
for i in VI_blanks_2005:
    result = np.where(blanks_2005 > blanks_2006)
    blanks_0506[result] = VI_blanks_2006[result]
    
# 2006 / 2007
blanks_0607 = np.zeros((2400, 2400))
for i in VI_blanks_2006:
    result = np.where(blanks_2006 > blanks_2007)
    blanks_0607[result] = VI_blanks_2007[result]

# 2007 / 2008
blanks_0708 = np.zeros((2400, 2400))
for i in VI_blanks_2007:
    result = np.where(blanks_2007 > blanks_2008)
    blanks_0708[result] = VI_blanks_2008[result]

# 2008 / 2009
blanks_0809 = np.zeros((2400, 2400))
for i in VI_blanks_2008:
    result = np.where(blanks_2008 > blanks_2009)
    blanks_0809[result] = VI_blanks_2009[result]
    
# 2009 / 2010
blanks_0910 = np.zeros((2400, 2400))
for i in VI_blanks_2009:
    result = np.where(blanks_2009 > blanks_2010)
    blanks_0910[result] = VI_blanks_2010[result]
    
# 2010 / 2011
blanks_1011 = np.zeros((2400, 2400))
for i in VI_blanks_2010:
    result = np.where(blanks_2010 > blanks_2011)
    blanks_1011[result] = VI_blanks_2011[result]

# 2011 / 2012
blanks_1112 = np.zeros((2400, 2400))
for i in VI_blanks_2011:
    result = np.where(blanks_2011 > blanks_2012)
    blanks_1112[result] = VI_blanks_2012[result]

# 2012 / 2013
blanks_1213 = np.zeros((2400, 2400))
for i in VI_blanks_2012:
    result = np.where(blanks_2012 > blanks_2013)
    blanks_1213[result] = VI_blanks_2013[result]
    
# 2013 / 2014
blanks_1314 = np.zeros((2400, 2400))
for i in VI_blanks_2013:
    result = np.where(blanks_2013 > blanks_2014)
    blanks_1314[result] = VI_blanks_2014[result]

# 2014 / 2015
blanks_1415 = np.zeros((2400, 2400))
for i in VI_blanks_2014:
    result = np.where(blanks_2014 > blanks_2015)
    blanks_1415[result] = VI_blanks_2015[result]
    
# 2015 / 2016
blanks_1516 = np.zeros((2400, 2400))
for i in VI_blanks_2015:
    result = np.where(blanks_2015 > blanks_2016)
    blanks_1516[result] = VI_blanks_2016[result]
    
# 2016 / 2017
blanks_1617 = np.zeros((2400, 2400))
for i in VI_blanks_2016:
    result = np.where(blanks_2016 > blanks_2017)
    blanks_1617[result] = VI_blanks_2017[result]

# 2017 / 2018
blanks_1718 = np.zeros((2400, 2400))
for i in VI_blanks_2017:
    result = np.where(blanks_2017 > blanks_2018)
    blanks_1718[result] = VI_blanks_2018[result]
    
# 2018 / 2019
blanks_1819 = np.zeros((2400, 2400))
for i in VI_blanks_2018:
    result = np.where(blanks_2018 > blanks_2019)
    blanks_1819[result] = VI_blanks_2019[result]

# %%
# 0203
for i in blanks_0203:
    result = np.where(blanks_0203 == 0)
    blanks_0203[result] = np.nan

# 0304
for i in blanks_0304:
    result = np.where(blanks_0304 == 0)
    blanks_0304[result] = np.nan

# 0405
for i in blanks_0405:
    result = np.where(blanks_0405 == 0)
    blanks_0405[result] = np.nan  

# 0506
for i in blanks_0506:
    result = np.where(blanks_0506 == 0)
    blanks_0506[result] = np.nan  
    
# 0607
for i in blanks_0607:
    result = np.where(blanks_0607 == 0)
    blanks_0607[result] = np.nan  

# 0708
for i in blanks_0708:
    result = np.where(blanks_0708 == 0)
    blanks_0708[result] = np.nan  

# 0809
for i in blanks_0809:
    result = np.where(blanks_0809 == 0)
    blanks_0809[result] = np.nan  
    
# 0910
for i in blanks_0910:
    result = np.where(blanks_0910 == 0)
    blanks_0910[result] = np.nan  
    
# 1011
for i in blanks_1011:
    result = np.where(blanks_1011 == 0)
    blanks_1011[result] = np.nan  
    
# 1112
for i in blanks_1112:
    result = np.where(blanks_1112 == 0)
    blanks_1112[result] = np.nan  
    
# 1213
for i in blanks_1213:
    result = np.where(blanks_1213 == 0)
    blanks_1213[result] = np.nan  
    
# 1314
for i in blanks_1314:
    result = np.where(blanks_1314 == 0)
    blanks_1314[result] = np.nan  
    
# 1415
for i in blanks_1415:
    result = np.where(blanks_1415 == 0)
    blanks_1415[result] = np.nan  

# 1516
for i in blanks_1516:
    result = np.where(blanks_1516 == 0)
    blanks_1516[result] = np.nan  

# 1617
for i in blanks_1617:
    result = np.where(blanks_1617 == 0)
    blanks_1617[result] = np.nan  

# 1718
for i in blanks_1718:
    result = np.where(blanks_1718 == 0)
    blanks_1718[result] = np.nan  

# 1819
for i in blanks_1819:
    result = np.where(blanks_1819 == 0)
    blanks_1819[result] = np.nan

# %%
# save text for analysis in another file - means I dont have to run through the code every time I want to analyse it
np.savetxt("D:\\masters_data\\output\\csv\\NDVI\\0203_decrease_NDVI.csv", blanks_0203, delimiter=",")
np.savetxt("D:\\masters_data\\output\\csv\\NDVI\\0304_decrease_NDVI.csv", blanks_0304, delimiter=",")
np.savetxt("D:\\masters_data\\output\\csv\\NDVI\\0405_decrease_NDVI.csv", blanks_0405, delimiter=",")
np.savetxt("D:\\masters_data\\output\\csv\\NDVI\\0506_decrease_NDVI.csv", blanks_0506, delimiter=",")
np.savetxt("D:\\masters_data\\output\\csv\\NDVI\\0607_decrease_NDVI.csv", blanks_0607, delimiter=",")
np.savetxt("D:\\masters_data\\output\\csv\\NDVI\\0708_decrease_NDVI.csv", blanks_0708, delimiter=",")
np.savetxt("D:\\masters_data\\output\\csv\\NDVI\\0809_decrease_NDVI.csv", blanks_0809, delimiter=",")
np.savetxt("D:\\masters_data\\output\\csv\\NDVI\\0910_decrease_NDVI.csv", blanks_0910, delimiter=",")
np.savetxt("D:\\masters_data\\output\\csv\\NDVI\\1011_decrease_NDVI.csv", blanks_1011, delimiter=",")
np.savetxt("D:\\masters_data\\output\\csv\\NDVI\\1112_decrease_NDVI.csv", blanks_1112, delimiter=",")
np.savetxt("D:\\masters_data\\output\\csv\\NDVI\\1213_decrease_NDVI.csv", blanks_1213, delimiter=",")
np.savetxt("D:\\masters_data\\output\\csv\\NDVI\\1314_decrease_NDVI.csv", blanks_1314, delimiter=",")
np.savetxt("D:\\masters_data\\output\\csv\\NDVI\\1415_decrease_NDVI.csv", blanks_1415, delimiter=",")
np.savetxt("D:\\masters_data\\output\\csv\\NDVI\\1516_decrease_NDVI.csv", blanks_1516, delimiter=",")
np.savetxt("D:\\masters_data\\output\\csv\\NDVI\\1617_decrease_NDVI.csv", blanks_1617, delimiter=",")
np.savetxt("D:\\masters_data\\output\\csv\\NDVI\\1718_decrease_NDVI.csv", blanks_1718, delimiter=",")
np.savetxt("D:\\masters_data\\output\\csv\\NDVI\\1819_decrease_NDVI.csv", blanks_1819, delimiter=",")

# %% [markdown]
# see file xx for further analysis
