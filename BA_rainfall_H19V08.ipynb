# %% [markdown]
# This notebook aims to create rainfall categories - but only for pixels with rainfall as selected e.g. Rainfall_min = 0.1

# %%
# Import libraries

import os
import glob
from osgeo import gdal
import numpy as np
import numpy.ma as ma
import matplotlib.pyplot as plt
import scipy.ndimage
import pandas as pd
import datetime as dt
import rasterio as rio
import re
import geopandas as gpd
import earthpy as et
import earthpy.plot as ep
import earthpy.spatial as es
import earthpy.mask as em
from pyhdf.SD import SD, SDC
import pprint
import matplotlib.colors as colors 
from mpl_toolkits.axes_grid1 import make_axes_locatable 
import csv
import pprint
import h5py 
import gdal
from gdalconst import *
import datetime

# %%
# Set input directory, and change working directory - plug in D drive
inDir = "D:\\masters_data\\MODIS_BA" 
os.chdir(inDir)                                                               # Change to working directory
outDir = os.path.normpath(os.path.split(inDir)[0] + os.sep + 'output') + '\\' # Create and set output directory
if not os.path.exists(outDir): os.makedirs(outDir)

# %%
# select MODIS files
MODISFiles = glob.glob('*H19V08*') 
First_MODISFiles = MODISFiles[:108]
Second_MODISFiles = MODISFiles[108:]
print(len(First_MODISFiles), len(Second_MODISFiles))
# Out:
# 108 108

# %%
# Set input directory, and change working directory - plug in D:
inDir = "D:\\masters_data\\output\\csv\\Rainfall\\H19_V08_arrays"
os.chdir(inDir)                                                               # Change to working directory
outDir = os.path.normpath(os.path.split(inDir)[0] + os.sep + 'output') + '\\' # Create and set output directory
if not os.path.exists(outDir): os.makedirs(outDir)

# %%
RainfallFiles = glob.glob('*rainfall*')
First_RainfallFiles = RainfallFiles[:108]
Second_RainfallFiles = RainfallFiles[108:]
print(len(First_MODISFiles), len(Second_MODISFiles))
# Out:
# 108 108

# %%
number = 0
for i in range(len(RainfallFiles)):
    MODISFile = MODISFiles[number]
    RainfallFile = RainfallFiles[number]
    
    date = MODISFile.split(".A"[1])[2].split(".h")[0]
    year = date[2:4]
    julian_day = date[4:]
    reformatted_dates = datetime.datetime.strptime(year + julian_day, '%y%j').date()
    MODISdate = reformatted_dates.strftime('%y_%m_%d')
    
    Rainfall_date = RainfallFile[2:10]

    print("MODIS: {0} \t Rainfall: {1}".format(MODISdate, Rainfall_date))
    number += 1
# Out:
# MODIS: 02_01_01 	 Rainfall: 02_01_01
# MODIS: 02_02_01 	 Rainfall: 02_02_01
# MODIS: 02_03_01 	 Rainfall: 02_03_01
# MODIS: 02_04_01 	 Rainfall: 02_04_01
# MODIS: 02_05_01 	 Rainfall: 02_05_01
# MODIS: 02_06_01 	 Rainfall: 02_06_01
# MODIS: 02_07_01 	 Rainfall: 02_07_01
# MODIS: 02_08_01 	 Rainfall: 02_08_01
# MODIS: 02_09_01 	 Rainfall: 02_09_01
# MODIS: 02_10_01 	 Rainfall: 02_10_01
# MODIS: 02_11_01 	 Rainfall: 02_11_01
# MODIS: 02_12_01 	 Rainfall: 02_12_01
# MODIS: 03_01_01 	 Rainfall: 03_01_01
# MODIS: 03_02_01 	 Rainfall: 03_02_01
# MODIS: 03_03_01 	 Rainfall: 03_03_01
# MODIS: 03_04_01 	 Rainfall: 03_04_01
# MODIS: 03_05_01 	 Rainfall: 03_05_01
# MODIS: 03_06_01 	 Rainfall: 03_06_01
# MODIS: 03_07_01 	 Rainfall: 03_07_01
# MODIS: 03_08_01 	 Rainfall: 03_08_01
# MODIS: 03_09_01 	 Rainfall: 03_09_01
# MODIS: 03_10_01 	 Rainfall: 03_10_01
# MODIS: 03_11_01 	 Rainfall: 03_11_01
# MODIS: 03_12_01 	 Rainfall: 03_12_01
# MODIS: 04_01_01 	 Rainfall: 04_01_01
# MODIS: 04_02_01 	 Rainfall: 04_02_01
# MODIS: 04_03_01 	 Rainfall: 04_03_01
# MODIS: 04_04_01 	 Rainfall: 04_04_01
# MODIS: 04_05_01 	 Rainfall: 04_05_01
# MODIS: 04_06_01 	 Rainfall: 04_06_01
# MODIS: 04_07_01 	 Rainfall: 04_07_01
# MODIS: 04_08_01 	 Rainfall: 04_08_01
# MODIS: 04_09_01 	 Rainfall: 04_09_01
# MODIS: 04_10_01 	 Rainfall: 04_10_01
# MODIS: 04_11_01 	 Rainfall: 04_11_01
# MODIS: 04_12_01 	 Rainfall: 04_12_01
# MODIS: 05_01_01 	 Rainfall: 05_01_01
# MODIS: 05_02_01 	 Rainfall: 05_02_01
# MODIS: 05_03_01 	 Rainfall: 05_03_01
# MODIS: 05_04_01 	 Rainfall: 05_04_01
# MODIS: 05_05_01 	 Rainfall: 05_05_01
# MODIS: 05_06_01 	 Rainfall: 05_06_01
# MODIS: 05_07_01 	 Rainfall: 05_07_01
# MODIS: 05_08_01 	 Rainfall: 05_08_01
# MODIS: 05_09_01 	 Rainfall: 05_09_01
# MODIS: 05_10_01 	 Rainfall: 05_10_01
# MODIS: 05_11_01 	 Rainfall: 05_11_01
# MODIS: 05_12_01 	 Rainfall: 05_12_01
# MODIS: 06_01_01 	 Rainfall: 06_01_01
# MODIS: 06_02_01 	 Rainfall: 06_02_01
# MODIS: 06_03_01 	 Rainfall: 06_03_01
# MODIS: 06_04_01 	 Rainfall: 06_04_01
# MODIS: 06_05_01 	 Rainfall: 06_05_01
# MODIS: 06_06_01 	 Rainfall: 06_06_01
# MODIS: 06_07_01 	 Rainfall: 06_07_01
# MODIS: 06_08_01 	 Rainfall: 06_08_01
# MODIS: 06_09_01 	 Rainfall: 06_09_01
# MODIS: 06_10_01 	 Rainfall: 06_10_01
# MODIS: 06_11_01 	 Rainfall: 06_11_01
# MODIS: 06_12_01 	 Rainfall: 06_12_01
# MODIS: 07_01_01 	 Rainfall: 07_01_01
# MODIS: 07_02_01 	 Rainfall: 07_02_01
# MODIS: 07_03_01 	 Rainfall: 07_03_01
# MODIS: 07_04_01 	 Rainfall: 07_04_01
# MODIS: 07_05_01 	 Rainfall: 07_05_01
# MODIS: 07_06_01 	 Rainfall: 07_06_01
# MODIS: 07_07_01 	 Rainfall: 07_07_01
# MODIS: 07_08_01 	 Rainfall: 07_08_01
# MODIS: 07_09_01 	 Rainfall: 07_09_01
# MODIS: 07_10_01 	 Rainfall: 07_10_01
# MODIS: 07_11_01 	 Rainfall: 07_11_01
# MODIS: 07_12_01 	 Rainfall: 07_12_01
# MODIS: 08_01_01 	 Rainfall: 08_01_01
# MODIS: 08_02_01 	 Rainfall: 08_02_01
# MODIS: 08_03_01 	 Rainfall: 08_03_01
# MODIS: 08_04_01 	 Rainfall: 08_04_01
# MODIS: 08_05_01 	 Rainfall: 08_05_01
# MODIS: 08_06_01 	 Rainfall: 08_06_01
# MODIS: 08_07_01 	 Rainfall: 08_07_01
# MODIS: 08_08_01 	 Rainfall: 08_08_01
# MODIS: 08_09_01 	 Rainfall: 08_09_01
# MODIS: 08_10_01 	 Rainfall: 08_10_01
# MODIS: 08_11_01 	 Rainfall: 08_11_01
# MODIS: 08_12_01 	 Rainfall: 08_12_01
# MODIS: 09_01_01 	 Rainfall: 09_01_01
# MODIS: 09_02_01 	 Rainfall: 09_02_01
# MODIS: 09_03_01 	 Rainfall: 09_03_01
# MODIS: 09_04_01 	 Rainfall: 09_04_01
# MODIS: 09_05_01 	 Rainfall: 09_05_01
# MODIS: 09_06_01 	 Rainfall: 09_06_01
# MODIS: 09_07_01 	 Rainfall: 09_07_01
# MODIS: 09_08_01 	 Rainfall: 09_08_01
# MODIS: 09_09_01 	 Rainfall: 09_09_01
# MODIS: 09_10_01 	 Rainfall: 09_10_01
# MODIS: 09_11_01 	 Rainfall: 09_11_01
# MODIS: 09_12_01 	 Rainfall: 09_12_01
# MODIS: 10_01_01 	 Rainfall: 10_01_01
# MODIS: 10_02_01 	 Rainfall: 10_02_01
# MODIS: 10_03_01 	 Rainfall: 10_03_01
# MODIS: 10_04_01 	 Rainfall: 10_04_01
# MODIS: 10_05_01 	 Rainfall: 10_05_01
# MODIS: 10_06_01 	 Rainfall: 10_06_01
# MODIS: 10_07_01 	 Rainfall: 10_07_01
# MODIS: 10_08_01 	 Rainfall: 10_08_01
# MODIS: 10_09_01 	 Rainfall: 10_09_01
# MODIS: 10_10_01 	 Rainfall: 10_10_01
# MODIS: 10_11_01 	 Rainfall: 10_11_01
# MODIS: 10_12_01 	 Rainfall: 10_12_01
# MODIS: 11_01_01 	 Rainfall: 11_01_01
# MODIS: 11_02_01 	 Rainfall: 11_02_01
# MODIS: 11_03_01 	 Rainfall: 11_03_01
# MODIS: 11_04_01 	 Rainfall: 11_04_01
# MODIS: 11_05_01 	 Rainfall: 11_05_01
# MODIS: 11_06_01 	 Rainfall: 11_06_01
# MODIS: 11_07_01 	 Rainfall: 11_07_01
# MODIS: 11_08_01 	 Rainfall: 11_08_01
# MODIS: 11_09_01 	 Rainfall: 11_09_01
# MODIS: 11_10_01 	 Rainfall: 11_10_01
# MODIS: 11_11_01 	 Rainfall: 11_11_01
# MODIS: 11_12_01 	 Rainfall: 11_12_01
# MODIS: 12_01_01 	 Rainfall: 12_01_01
# MODIS: 12_02_01 	 Rainfall: 12_02_01
# MODIS: 12_03_01 	 Rainfall: 12_03_01
# MODIS: 12_04_01 	 Rainfall: 12_04_01
# MODIS: 12_05_01 	 Rainfall: 12_05_01
# MODIS: 12_06_01 	 Rainfall: 12_06_01
# MODIS: 12_07_01 	 Rainfall: 12_07_01
# MODIS: 12_08_01 	 Rainfall: 12_08_01
# MODIS: 12_09_01 	 Rainfall: 12_09_01
# MODIS: 12_10_01 	 Rainfall: 12_10_01
# MODIS: 12_11_01 	 Rainfall: 12_11_01
# MODIS: 12_12_01 	 Rainfall: 12_12_01
# MODIS: 13_01_01 	 Rainfall: 13_01_01
# MODIS: 13_02_01 	 Rainfall: 13_02_01
# MODIS: 13_03_01 	 Rainfall: 13_03_01
# MODIS: 13_04_01 	 Rainfall: 13_04_01
# MODIS: 13_05_01 	 Rainfall: 13_05_01
# MODIS: 13_06_01 	 Rainfall: 13_06_01
# MODIS: 13_07_01 	 Rainfall: 13_07_01
# MODIS: 13_08_01 	 Rainfall: 13_08_01
# MODIS: 13_09_01 	 Rainfall: 13_09_01
# MODIS: 13_10_01 	 Rainfall: 13_10_01
# MODIS: 13_11_01 	 Rainfall: 13_11_01
# MODIS: 13_12_01 	 Rainfall: 13_12_01
# MODIS: 14_01_01 	 Rainfall: 14_01_01
# MODIS: 14_02_01 	 Rainfall: 14_02_01
# MODIS: 14_03_01 	 Rainfall: 14_03_01
# MODIS: 14_04_01 	 Rainfall: 14_04_01
# MODIS: 14_05_01 	 Rainfall: 14_05_01
# MODIS: 14_06_01 	 Rainfall: 14_06_01
# MODIS: 14_07_01 	 Rainfall: 14_07_01
# MODIS: 14_08_01 	 Rainfall: 14_08_01
# MODIS: 14_09_01 	 Rainfall: 14_09_01
# MODIS: 14_10_01 	 Rainfall: 14_10_01
# MODIS: 14_11_01 	 Rainfall: 14_11_01
# MODIS: 14_12_01 	 Rainfall: 14_12_01
# MODIS: 15_01_01 	 Rainfall: 15_01_01
# MODIS: 15_02_01 	 Rainfall: 15_02_01
# MODIS: 15_03_01 	 Rainfall: 15_03_01
# MODIS: 15_04_01 	 Rainfall: 15_04_01
# MODIS: 15_05_01 	 Rainfall: 15_05_01
# MODIS: 15_06_01 	 Rainfall: 15_06_01
# MODIS: 15_07_01 	 Rainfall: 15_07_01
# MODIS: 15_08_01 	 Rainfall: 15_08_01
# MODIS: 15_09_01 	 Rainfall: 15_09_01
# MODIS: 15_10_01 	 Rainfall: 15_10_01
# MODIS: 15_11_01 	 Rainfall: 15_11_01
# MODIS: 15_12_01 	 Rainfall: 15_12_01
# MODIS: 16_01_01 	 Rainfall: 16_01_01
# MODIS: 16_02_01 	 Rainfall: 16_02_01
# MODIS: 16_03_01 	 Rainfall: 16_03_01
# MODIS: 16_04_01 	 Rainfall: 16_04_01
# MODIS: 16_05_01 	 Rainfall: 16_05_01
# MODIS: 16_06_01 	 Rainfall: 16_06_01
# MODIS: 16_07_01 	 Rainfall: 16_07_01
# MODIS: 16_08_01 	 Rainfall: 16_08_01
# MODIS: 16_09_01 	 Rainfall: 16_09_01
# MODIS: 16_10_01 	 Rainfall: 16_10_01
# MODIS: 16_11_01 	 Rainfall: 16_11_01
# MODIS: 16_12_01 	 Rainfall: 16_12_01
# MODIS: 17_01_01 	 Rainfall: 17_01_01
# MODIS: 17_02_01 	 Rainfall: 17_02_01
# MODIS: 17_03_01 	 Rainfall: 17_03_01
# MODIS: 17_04_01 	 Rainfall: 17_04_01
# MODIS: 17_05_01 	 Rainfall: 17_05_01
# MODIS: 17_06_01 	 Rainfall: 17_06_01
# MODIS: 17_07_01 	 Rainfall: 17_07_01
# MODIS: 17_08_01 	 Rainfall: 17_08_01
# MODIS: 17_09_01 	 Rainfall: 17_09_01
# MODIS: 17_10_01 	 Rainfall: 17_10_01
# MODIS: 17_11_01 	 Rainfall: 17_11_01
# MODIS: 17_12_01 	 Rainfall: 17_12_01
# MODIS: 18_01_01 	 Rainfall: 18_01_01
# MODIS: 18_02_01 	 Rainfall: 18_02_01
# MODIS: 18_03_01 	 Rainfall: 18_03_01
# MODIS: 18_04_01 	 Rainfall: 18_04_01
# MODIS: 18_05_01 	 Rainfall: 18_05_01
# MODIS: 18_06_01 	 Rainfall: 18_06_01
# MODIS: 18_07_01 	 Rainfall: 18_07_01
# MODIS: 18_08_01 	 Rainfall: 18_08_01
# MODIS: 18_09_01 	 Rainfall: 18_09_01
# MODIS: 18_10_01 	 Rainfall: 18_10_01
# MODIS: 18_11_01 	 Rainfall: 18_11_01
# MODIS: 18_12_01 	 Rainfall: 18_12_01
# MODIS: 19_01_01 	 Rainfall: 19_01_01
# MODIS: 19_02_01 	 Rainfall: 19_02_01
# MODIS: 19_03_01 	 Rainfall: 19_03_01
# MODIS: 19_04_01 	 Rainfall: 19_04_01
# MODIS: 19_05_01 	 Rainfall: 19_05_01
# MODIS: 19_06_01 	 Rainfall: 19_06_01
# MODIS: 19_07_01 	 Rainfall: 19_07_01
# MODIS: 19_08_01 	 Rainfall: 19_08_01
# MODIS: 19_09_01 	 Rainfall: 19_09_01
# MODIS: 19_10_01 	 Rainfall: 19_10_01
# MODIS: 19_11_01 	 Rainfall: 19_11_01
# MODIS: 19_12_01 	 Rainfall: 19_12_01

# %% [markdown]
# H19V08

# %%
# create BA array for first 9 years (2002 - 2010)
inDir = "D:\\masters_data\\MODIS_BA" 
os.chdir(inDir)

first_BA = np.zeros((2400, 2400))
NUMBER = 0

for j in First_MODISFiles:
    inDir = "D:\\masters_data\\output\\csv\\Rainfall\\H19_V08_arrays"
    os.chdir(inDir)
    RainfallFile = pd.read_csv(First_RainfallFiles[NUMBER], header =None)
    mask = np.zeros((2400, 2400))
    mask[(RainfallFile <= 500) == 1] = 1
    
    inDir = "D:\\masters_data\\MODIS_BA" 
    os.chdir(inDir)
    filename= First_MODISFiles[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(First_MODISFiles[NUMBER]) as dataset:
        crs = dataset.read_crs()
    
    file_name = First_MODISFiles[NUMBER]
    file = SD(file_name, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where((data > 0) *(mask==1))
    
    first_BA[result] += 1
    
    
    NUMBER += 1
# Out:
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-14-3761d8ea13fa> in <module>
#       9     inDir = "D:\\masters_data\\output\\csv\\Rainfall\\H19_V08_arrays"
#      10     os.chdir(inDir)
# ---> 11     RainfallFile = pd.read_csv(First_RainfallFiles[NUMBER], header =None)
#      12     mask = np.zeros((2400, 2400))
#      13     mask[(RainfallFile <= 500) == 1] = 1
#
# ~\miniconda3\envs\GDAL_test\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~\miniconda3\envs\GDAL_test\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     456
#     457     try:
# --> 458         data = parser.read(nrows)
#     459     finally:
#     460         parser.close()
#
# ~\miniconda3\envs\GDAL_test\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1184     def read(self, nrows=None):
#    1185         nrows = _validate_integer("nrows", nrows)
# -> 1186         ret = self._engine.read(nrows)
#    1187
#    1188         # May alter columns / col_dict
#
# ~\miniconda3\envs\GDAL_test\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2143     def read(self, nrows=None):
#    2144         try:
# -> 2145             data = self._reader.read(nrows)
#    2146         except StopIteration:
#    2147             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
# create BA array for first 9 years (2002 - 2010)
# issue im adding one every time theres a fire but resetting it if rainfall is less than .1!
inDir = "D:\\masters_data\\MODIS_BA" 
os.chdir(inDir)

second_BA = np.zeros((2400, 2400))
NUMBER = 0

for j in Second_MODISFiles:
    inDir = "D:\\masters_data\\output\\csv\\Rainfall\\H19_V08_arrays"
    os.chdir(inDir)
    RainfallFile = pd.read_csv(Second_RainfallFiles[NUMBER], header =None)
    mask = np.zeros((2400, 2400))
    mask[(RainfallFile <= 500) == 1] = 1
    
    inDir = "D:\\masters_data\\MODIS_BA" 
    os.chdir(inDir)
    filename= Second_MODISFiles[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(filename) as dataset:
        crs = dataset.read_crs()
    
    file = SD(filename, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where((data > 0) *(mask==1))
    
    second_BA[result] += 1
    
    
    NUMBER += 1
# Out:
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %%
np.savetxt("D:\\masters_data\\rainfall\\Rainfall_bands\\H19_V08\\first_BA_sub500_H19V08.csv", first_BA, delimiter=",")
np.savetxt("D:\\masters_data\\rainfall\\Rainfall_bands\\H19_V08\\second_BA_sub500_H19V08.csv", second_BA, delimiter=",")

# %%
# create BA array for first 9 years (2002 - 2010)
inDir = "D:\\masters_data\\MODIS_BA" 
os.chdir(inDir)

first_BA = np.zeros((2400, 2400))
NUMBER = 0

for j in First_MODISFiles:
    inDir = "D:\\masters_data\\output\\csv\\Rainfall\\H19_V08_arrays"
    os.chdir(inDir)
    RainfallFile = pd.read_csv(First_RainfallFiles[NUMBER], header =None)
    mask = np.zeros((2400, 2400))
    mask[((RainfallFile >= 500)*(RainfallFile <= 1500)) == 1] = 1
    
    inDir = "D:\\masters_data\\MODIS_BA" 
    os.chdir(inDir)
    filename= First_MODISFiles[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(First_MODISFiles[NUMBER]) as dataset:
        crs = dataset.read_crs()
    
    file_name = First_MODISFiles[NUMBER]
    file = SD(file_name, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where((data > 0) *(mask==1))
    
    first_BA[result] += 1
    
    NUMBER += 1
# Out:
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-8-fd355540ac9f> in <module>
#       9     inDir = "D:\\masters_data\\output\\csv\\Rainfall\\H19_V08_arrays"
#      10     os.chdir(inDir)
# ---> 11     RainfallFile = pd.read_csv(First_RainfallFiles[NUMBER], header =None)
#      12     mask = np.zeros((2400, 2400))
#      13     mask[((RainfallFile >= 500)*(RainfallFile <= 1500)) == 1] = 1
#
# ~\miniconda3\envs\GDAL_test\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~\miniconda3\envs\GDAL_test\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     456
#     457     try:
# --> 458         data = parser.read(nrows)
#     459     finally:
#     460         parser.close()
#
# ~\miniconda3\envs\GDAL_test\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1184     def read(self, nrows=None):
#    1185         nrows = _validate_integer("nrows", nrows)
# -> 1186         ret = self._engine.read(nrows)
#    1187
#    1188         # May alter columns / col_dict
#
# ~\miniconda3\envs\GDAL_test\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2143     def read(self, nrows=None):
#    2144         try:
# -> 2145             data = self._reader.read(nrows)
#    2146         except StopIteration:
#    2147             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
# create BA array for first 9 years (2002 - 2010)
# issue im adding one every time theres a fire but resetting it if rainfall is less than .1!
inDir = "D:\\masters_data\\MODIS_BA" 
os.chdir(inDir)

second_BA = np.zeros((2400, 2400))
NUMBER = 0

for j in Second_MODISFiles:
    inDir = "D:\\masters_data\\output\\csv\\Rainfall\\H19_V08_arrays"
    os.chdir(inDir)
    RainfallFile = pd.read_csv(Second_RainfallFiles[NUMBER], header =None)
    mask = np.zeros((2400, 2400))
    mask[((RainfallFile >= 500)*(RainfallFile <= 1500)) == 1] = 1
    
    inDir = "D:\\masters_data\\MODIS_BA" 
    os.chdir(inDir)
    filename= Second_MODISFiles[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(filename) as dataset:
        crs = dataset.read_crs()
    
    file = SD(filename, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where((data > 0) *(mask==1))
    
    second_BA[result] += 1
    
    
    NUMBER += 1
# Out:
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\pandas\core\computation\expressions.py:200: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %%
np.savetxt("D:\\masters_data\\rainfall\\Rainfall_bands\\H19_V08\\first_BA_500-1500_H19V08.csv", first_BA, delimiter=",")
np.savetxt("D:\\masters_data\\rainfall\\Rainfall_bands\\H19_V08\\second_BA_500-1500_H19V08.csv", second_BA, delimiter=",")

# %%
# create BA array for first 9 years (2002 - 2010)
inDir = "D:\\masters_data\\MODIS_BA" 
os.chdir(inDir)

first_BA = np.zeros((2400, 2400))
NUMBER = 0

for j in First_MODISFiles:
    inDir = "D:\\masters_data\\output\\csv\\Rainfall\\H19_V08_arrays"
    os.chdir(inDir)
    RainfallFile = pd.read_csv(First_RainfallFiles[NUMBER], header =None)
    mask = np.zeros((2400, 2400))
    mask[(RainfallFile >= 1500) == 1] = 1
    
    inDir = "D:\\masters_data\\MODIS_BA" 
    os.chdir(inDir)
    filename= First_MODISFiles[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(First_MODISFiles[NUMBER]) as dataset:
        crs = dataset.read_crs()
    
    file_name = First_MODISFiles[NUMBER]
    file = SD(file_name, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where((data > 0) *(mask==1))
    
    first_BA[result] += 1
    
    
    NUMBER += 1
# Out:
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-11-b291ddc349c2> in <module>
#       9     inDir = "D:\\masters_data\\output\\csv\\Rainfall\\H19_V08_arrays"
#      10     os.chdir(inDir)
# ---> 11     RainfallFile = pd.read_csv(First_RainfallFiles[NUMBER], header =None)
#      12     mask = np.zeros((2400, 2400))
#      13     mask[(RainfallFile >= 1500) == 1] = 1
#
# ~\miniconda3\envs\GDAL_test\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~\miniconda3\envs\GDAL_test\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     456
#     457     try:
# --> 458         data = parser.read(nrows)
#     459     finally:
#     460         parser.close()
#
# ~\miniconda3\envs\GDAL_test\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1184     def read(self, nrows=None):
#    1185         nrows = _validate_integer("nrows", nrows)
# -> 1186         ret = self._engine.read(nrows)
#    1187
#    1188         # May alter columns / col_dict
#
# ~\miniconda3\envs\GDAL_test\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2143     def read(self, nrows=None):
#    2144         try:
# -> 2145             data = self._reader.read(nrows)
#    2146         except StopIteration:
#    2147             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
# create BA array for first 9 years (2002 - 2010)
# issue im adding one every time theres a fire but resetting it if rainfall is less than .1!
inDir = "D:\\masters_data\\MODIS_BA" 
os.chdir(inDir)

second_BA = np.zeros((2400, 2400))
NUMBER = 0

for j in Second_MODISFiles:
    inDir = "D:\\masters_data\\output\\csv\\Rainfall\\H19_V08_arrays"
    os.chdir(inDir)
    RainfallFile = pd.read_csv(Second_RainfallFiles[NUMBER], header =None)
    mask = np.zeros((2400, 2400))
    mask[(RainfallFile >= 1500) == 1] = 1
    
    inDir = "D:\\masters_data\\MODIS_BA" 
    os.chdir(inDir)
    filename= Second_MODISFiles[NUMBER]
    dataset = gdal.Open(filename,GA_ReadOnly)
    subdataset = dataset.GetSubDatasets()[1]
    
    with rio.open(filename) as dataset:
        crs = dataset.read_crs()
    
    file = SD(filename, SDC.READ)   
    
    datasets_dic = file.datasets()
    sds_obj = file.select(0)
    data = sds_obj.get() 
    result = np.where((data > 0) *(mask==1))
    
    second_BA[result] += 1
    
    
    NUMBER += 1
# Out:
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\samgr\miniconda3\envs\GDAL_test\lib\site-packages\rasterio\__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %%
np.savetxt("D:\\masters_data\\rainfall\\Rainfall_bands\\H19_V08\\first_above_1500_H19V08.csv", first_BA, delimiter=",")
np.savetxt("D:\\masters_data\\rainfall\\Rainfall_bands\\H19_V08\\second_BA_above_1500_H19V08.csv", second_BA, delimiter=",")
